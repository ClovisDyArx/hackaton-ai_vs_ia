# %%
import os

import pandas as pd
import s3fs
import zipfile

# %%
S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]
fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': S3_ENDPOINT_URL})

# %%
fs.ls("gvimont/diffusion/hackathon-minarm-2024")
# Out:
# ['gvimont/diffusion/hackathon-minarm-2024/AIVSAI',
#  'gvimont/diffusion/hackathon-minarm-2024/Acoustique',
#  'gvimont/diffusion/hackathon-minarm-2024/Similarité']

# %%
fs.ls("gvimont/diffusion/hackathon-minarm-2024/AIVSAI")
# Out:
# ['gvimont/diffusion/hackathon-minarm-2024/AIVSAI/.keep',
#  'gvimont/diffusion/hackathon-minarm-2024/AIVSAI/HC3.zip']

# %%
PATH_IN = 'gvimont/diffusion/hackathon-minarm-2024/AIVSAI/HC3.zip'
fs.download(PATH_IN, 'data/HC3.zip')
# Out:
# [None]

# %%
with zipfile.ZipFile("data/HC3.zip","r") as zip_file:
    zip_file.extractall("data/")

# %%
df_finance = pd.read_json('data/HC3/finance.jsonl', lines=True)

# %%
df_finance.head()
# Out:
#                                             question  \
# 0  Historical P/E ratios of small-cap vs. large-c...
# 1  Should you co-sign a personal loan for a frien...
# 2  Should I avoid credit card use to improve our ...
# 3  Difference between 'split and redemption' of s...
# 4     Pros & cons of investing in gold vs. platinum?
#
#                                        human_answers  \
# 0  [There is most likely an error in the WSJ's da...
# 1  [I know this question has a lot of answers alr...
# 2  [If you pay it off before the cycle closes it ...
# 3  [It is the first time I encounter redemption p...
# 4  [Why Investors Buy Platinum is an old (1995) a...
#
#                                      chatgpt_answers
# 0  [Historical price-to-earnings (P/E) ratios for...
# 1  [Co-signing a personal loan for a friend or fa...
# 2  [It can be a good idea to avoid using credit c...
# 3  [Share split and redemption are two different ...
# 4  [Gold and platinum are both precious metals th...

# %%
df_medicine = pd.read_json('data/HC3/medicine.jsonl', lines=True)
df_medicine.head()
# Out:
#                                             question  \
# 0  Does Primolut N taken during pregnancy affect ...
# 1  Bloating and pain on right lower abdomen. Shou...
# 2  Is chest pain related to intake of clindamycin...
# 3  Q. Noticed a yellowish sag in the gums of my 1...
# 4  Suggest remedy for low grade fever, hot and co...
#
#                                        human_answers  \
# 0  [Hi,     Thanks for the query. I understand yo...
# 1  [Hello,Thanks for the query to H.C.M. Forum.Pa...
# 2  [Hello, The use of Clindamycin can cause stoma...
# 3  [Hello. Revert back with the photos to a denti...
# 4  [Hi Dear,Welcome to Healthcaremagic Team.Under...
#
#                                      chatgpt_answers
# 0  [It is not recommended to use Primolut N durin...
# 1  [If you are experiencing abdominal pain and bl...
# 2  [It is possible that chest pain could be relat...
# 3  [It is difficult to accurately diagnose a cond...
# 4  [I'm sorry to hear that you're feeling sick. I...

# %%
df_open_qa = pd.read_json('data/HC3/open_qa.jsonl', lines=True)
df_open_qa.head()
# Out:
#                                  question  \
# 0           what composer used sound mass
# 1    where did the persian war take place
# 2                        what are add ons
# 3                 how does a dredge work?
# 4  what classes are considered humanities
#
#                                        human_answers  \
# 0  [Composers and works include Barbara Kolb , Pa...
# 1  [The Greco-Persian Wars (also often called the...
# 2  [Plug-in (computing) , a piece of software whi...
# 3  [Dredging is an excavation activity or operati...
# 4  [The humanities are academic disciplines that ...
#
#                                      chatgpt_answers
# 0  [Sound mass is a term used to describe a type ...
# 1  [The Persian Wars were a series of conflicts f...
# 2  [Add-ons, also known as extensions or plug-ins...
# 3  [A dredge is a piece of equipment that is used...
# 4  [Humanities are academic disciplines that stud...

# %%
df_wiki = pd.read_json('data/HC3/wiki_csai.jsonl', lines=True)
df_wiki
# Out:
#                                               question  \
# 0            Please explain what is "Animal cognition"
# 1          Please explain what is "Human intelligence"
# 2    Please explain what is "Oxford English Diction...
# 3     Please explain what is "Oxford University Press"
# 4             Please explain what is "AI applications"
# ..                                                 ...
# 837             Please explain what is "Punched cards"
# 838                Please explain what is "Paper tape"
# 839               Please explain what is "BBC Model B"
# 840                   Please explain what is "O level"
# 841                   Please explain what is "A level"
#
#                                          human_answers  \
# 0    [Animal cognition encompasses the mental capac...
# 1    [Human intelligence is the intellectual capabi...
# 2    [The Oxford English Dictionary (OED) is the fi...
# 3    [Oxford University Press (OUP) is the universi...
# 4    [Artificial intelligence (AI) has been used in...
# ..                                                 ...
# 837  [A punched card (also punch card or punched-ca...
# 838  [Punched tape or perforated paper tape is a fo...
# 839  [The British Broadcasting Corporation Microcom...
# 840  [The O-Level (Ordinary Level) is a subject-bas...
# 841  [The A-Level (Advanced Level) is a subject-bas...
#
#                                        chatgpt_answers
# 0    [Animal cognition refers to the mental capacit...
# 1    [Human intelligence is the mental ability to t...
# 2    [The Oxford English Dictionary (OED) is a comp...
# 3    [Oxford University Press (OUP) is a department...
# 4    [AI applications are computer systems that are...
# ..                                                 ...
# 837  [Punched cards were a means of storing and pro...
# 838  [Paper tape is a medium for storing and transm...
# 839  [The BBC Model B is a computer that was made b...
# 840  ["O level" refers to the General Certificate o...
# 841  [A level, or Advanced level, is a qualificatio...
#
# [842 rows x 3 columns]

# %%
df = pd.concat([df_finance, df_medicine, df_open_qa, df_wiki], ignore_index=True)

df
# Out:
#                                                question  \
# 0     Historical P/E ratios of small-cap vs. large-c...
# 1     Should you co-sign a personal loan for a frien...
# 2     Should I avoid credit card use to improve our ...
# 3     Difference between 'split and redemption' of s...
# 4        Pros & cons of investing in gold vs. platinum?
# ...                                                 ...
# 7205             Please explain what is "Punched cards"
# 7206                Please explain what is "Paper tape"
# 7207               Please explain what is "BBC Model B"
# 7208                   Please explain what is "O level"
# 7209                   Please explain what is "A level"
#
#                                           human_answers  \
# 0     [There is most likely an error in the WSJ's da...
# 1     [I know this question has a lot of answers alr...
# 2     [If you pay it off before the cycle closes it ...
# 3     [It is the first time I encounter redemption p...
# 4     [Why Investors Buy Platinum is an old (1995) a...
# ...                                                 ...
# 7205  [A punched card (also punch card or punched-ca...
# 7206  [Punched tape or perforated paper tape is a fo...
# 7207  [The British Broadcasting Corporation Microcom...
# 7208  [The O-Level (Ordinary Level) is a subject-bas...
# 7209  [The A-Level (Advanced Level) is a subject-bas...
#
#                                         chatgpt_answers
# 0     [Historical price-to-earnings (P/E) ratios for...
# 1     [Co-signing a personal loan for a friend or fa...
# 2     [It can be a good idea to avoid using credit c...
# 3     [Share split and redemption are two different ...
# 4     [Gold and platinum are both precious metals th...
# ...                                                 ...
# 7205  [Punched cards were a means of storing and pro...
# 7206  [Paper tape is a medium for storing and transm...
# 7207  [The BBC Model B is a computer that was made b...
# 7208  ["O level" refers to the General Certificate o...
# 7209  [A level, or Advanced level, is a qualificatio...
#
# [7210 rows x 3 columns]

# %%
def compter_mots(texte_liste):
    texte = " ".join(texte_liste)
    return len(texte.split())

# Appliquer la fonction aux colonnes 2 et 3 pour compter le nombre de mots
df['Nombre de mots dans Réponse Humaine'] = df['human_answers'].apply(compter_mots)
df['Nombre de mots dans Réponse GPT'] = df['chatgpt_answers'].apply(compter_mots)

# Calculer le nombre moyen de mots moyen dans les colonnes 2 et 3
moyenne_reponse_humain = df['Nombre de mots dans Réponse Humaine'].mean()
moyenne_reponse_gpt = df['Nombre de mots dans Réponse GPT'].mean()

print("Nombre moyen de mots dans Réponse Humaine :", moyenne_reponse_humain)
print("Nombre moyen de mots dans Réponse GPT :", moyenne_reponse_gpt)
# Out:
# Nombre moyen de mots dans Réponse Humaine : 138.03314840499306
# Nombre moyen de mots dans Réponse GPT : 241.70097087378642

# %%
# Liste des analyses à effectuer sur le dataset 
# Etape 1 : Informations générales  
# Etape 2 : Rajouter la source des questions 
# Etape 3 : Calcul du nombre de reponses par source (bar chart)
# Etape 4 : Calcul du nombre moyen de mots par réponse par source (bar chart)
# Etape 5 : Identification des mots clés

# %%
# ETAPE 1 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7210 entries, 0 to 7209
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   question                             7210 non-null   object
#  1   human_answers                        7210 non-null   object
#  2   chatgpt_answers                      7210 non-null   object
#  3   Nombre de mots dans Réponse Humaine  7210 non-null   int64
#  4   Nombre de mots dans Réponse GPT      7210 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 281.8+ KB

# %%
# ETAPE 2
# Rajouter la source de chaque dataset

# Finance 
df_finance['source'] = 'finance'
df_finance
# Out:
#                                                question  \
# 0     Historical P/E ratios of small-cap vs. large-c...
# 1     Should you co-sign a personal loan for a frien...
# 2     Should I avoid credit card use to improve our ...
# 3     Difference between 'split and redemption' of s...
# 4        Pros & cons of investing in gold vs. platinum?
# ...                                                 ...
# 3928  Challenged an apparently bogus credit card cha...
# 3929  Does a stay at home mom need term life insurance?
# 3930             Rules for SEP contributions in an LLC?
# 3931  How do credit card payments work? What ensures...
# 3932                               Beginning investment
#
#                                           human_answers  \
# 0     [There is most likely an error in the WSJ's da...
# 1     [I know this question has a lot of answers alr...
# 2     [If you pay it off before the cycle closes it ...
# 3     [It is the first time I encounter redemption p...
# 4     [Why Investors Buy Platinum is an old (1995) a...
# ...                                                 ...
# 3928  [Yes.  For $15 it's not worth anyone's time to...
# 3929  [Another source of insurance can be through th...
# 3930  [From Schwab -  What are the eligibility requi...
# 3931  [Your credit card limit is nothing more than a...
# 3932  [I am a huge fan of jim Cramer and while you m...
#
#                                         chatgpt_answers   source
# 0     [Historical price-to-earnings (P/E) ratios for...  finance
# 1     [Co-signing a personal loan for a friend or fa...  finance
# 2     [It can be a good idea to avoid using credit c...  finance
# 3     [Share split and redemption are two different ...  finance
# 4     [Gold and platinum are both precious metals th...  finance
# ...                                                 ...      ...
# 3928  [If you have challenged a credit card charge t...  finance
# 3929  [It is generally a good idea for stay-at-home ...  finance
# 3930  [A SEP (Simplified Employee Pension) is a type...  finance
# 3931  [When you make a purchase with a credit card, ...  finance
# 3932  [If you're interested in beginning your invest...  finance
#
# [3933 rows x 4 columns]

# %%
# Medicine 
df_medicine['source'] = 'medicine'
df_medicine
# Out:
#                                                question  \
# 0     Does Primolut N taken during pregnancy affect ...
# 1     Bloating and pain on right lower abdomen. Shou...
# 2     Is chest pain related to intake of clindamycin...
# 3     Q. Noticed a yellowish sag in the gums of my 1...
# 4     Suggest remedy for low grade fever, hot and co...
# ...                                                 ...
# 1243  Is rise in pressure from 116/66 to 140/80 norm...
# 1244  What could cause a painless lump in the right ...
# 1245  Can Acutret be given to a child for treatment ...
# 1246  Are BP of 119/65 and pulse of 35 causes for co...
# 1247  Suggest treatment for back pain after walking ...
#
#                                           human_answers  \
# 0     [Hi,     Thanks for the query. I understand yo...
# 1     [Hello,Thanks for the query to H.C.M. Forum.Pa...
# 2     [Hello, The use of Clindamycin can cause stoma...
# 3     [Hello. Revert back with the photos to a denti...
# 4     [Hi Dear,Welcome to Healthcaremagic Team.Under...
# ...                                                 ...
# 1243  [Hello!Welcome and thank you for asking on HCM...
# 1244  [Hi, * As per my surgical experience, the issu...
# 1245  [Although it is difficult to comment whether A...
# 1246  [Welcome and thank you for asking on HCM! I ha...
# 1247  [Hi,Having this type of back pain at this age ...
#
#                                         chatgpt_answers    source
# 0     [It is not recommended to use Primolut N durin...  medicine
# 1     [If you are experiencing abdominal pain and bl...  medicine
# 2     [It is possible that chest pain could be relat...  medicine
# 3     [It is difficult to accurately diagnose a cond...  medicine
# 4     [I'm sorry to hear that you're feeling sick. I...  medicine
# ...                                                 ...       ...
# 1243  [It's not uncommon for blood pressure to fluct...  medicine
# 1244  [There are several possible causes of a painle...  medicine
# 1245  [It is not appropriate for me to recommend a s...  medicine
# 1246  [It is not uncommon for people with rheumatoid...  medicine
# 1247  [It is not uncommon to experience back pain, e...  medicine
#
# [1248 rows x 4 columns]

# %%
# Open Qa 
df_open_qa['source'] = 'open_qa'
df_open_qa
# Out:
#                                                question  \
# 0                         what composer used sound mass
# 1                  where did the persian war take place
# 2                                      what are add ons
# 3                               how does a dredge work?
# 4                what classes are considered humanities
# ...                                                 ...
# 1182                           when did secretariat win
# 1183                          what is a full job time??
# 1184  what are the three primary colors in the subtr...
# 1185                  what are layers of the ionosphere
# 1186                       what state is new orleans in
#
#                                           human_answers  \
# 0     [Composers and works include Barbara Kolb , Pa...
# 1     [The Greco-Persian Wars (also often called the...
# 2     [Plug-in (computing) , a piece of software whi...
# 3     [Dredging is an excavation activity or operati...
# 4     [The humanities are academic disciplines that ...
# ...                                                 ...
# 1182  [Secretariat (March 30, 1970 – October 4, 1989...
# 1183  [Full-time employment is employment in which a...
# 1184  [The overlapping subtractive yellow, cyan and ...
# 1185  [The ionosphere is a region of the upper atmos...
# 1186  [New Orleans ( or , locally or ; ) is a major ...
#
#                                         chatgpt_answers   source
# 0     [Sound mass is a term used to describe a type ...  open_qa
# 1     [The Persian Wars were a series of conflicts f...  open_qa
# 2     [Add-ons, also known as extensions or plug-ins...  open_qa
# 3     [A dredge is a piece of equipment that is used...  open_qa
# 4     [Humanities are academic disciplines that stud...  open_qa
# ...                                                 ...      ...
# 1182  [Secretariat was an American Thoroughbred race...  open_qa
# 1183  [A full-time job typically refers to a job tha...  open_qa
# 1184  [The three primary colors in the subtractive c...  open_qa
# 1185  [The ionosphere is a region of Earth's upper a...  open_qa
# 1186  [New Orleans is a city located in the state of...  open_qa
#
# [1187 rows x 4 columns]

# %%
# Wiki 
df_wiki['source'] = 'wiki_csai'
df_wiki
# Out:
#                                               question  \
# 0            Please explain what is "Animal cognition"
# 1          Please explain what is "Human intelligence"
# 2    Please explain what is "Oxford English Diction...
# 3     Please explain what is "Oxford University Press"
# 4             Please explain what is "AI applications"
# ..                                                 ...
# 837             Please explain what is "Punched cards"
# 838                Please explain what is "Paper tape"
# 839               Please explain what is "BBC Model B"
# 840                   Please explain what is "O level"
# 841                   Please explain what is "A level"
#
#                                          human_answers  \
# 0    [Animal cognition encompasses the mental capac...
# 1    [Human intelligence is the intellectual capabi...
# 2    [The Oxford English Dictionary (OED) is the fi...
# 3    [Oxford University Press (OUP) is the universi...
# 4    [Artificial intelligence (AI) has been used in...
# ..                                                 ...
# 837  [A punched card (also punch card or punched-ca...
# 838  [Punched tape or perforated paper tape is a fo...
# 839  [The British Broadcasting Corporation Microcom...
# 840  [The O-Level (Ordinary Level) is a subject-bas...
# 841  [The A-Level (Advanced Level) is a subject-bas...
#
#                                        chatgpt_answers     source
# 0    [Animal cognition refers to the mental capacit...  wiki_csai
# 1    [Human intelligence is the mental ability to t...  wiki_csai
# 2    [The Oxford English Dictionary (OED) is a comp...  wiki_csai
# 3    [Oxford University Press (OUP) is a department...  wiki_csai
# 4    [AI applications are computer systems that are...  wiki_csai
# ..                                                 ...        ...
# 837  [Punched cards were a means of storing and pro...  wiki_csai
# 838  [Paper tape is a medium for storing and transm...  wiki_csai
# 839  [The BBC Model B is a computer that was made b...  wiki_csai
# 840  ["O level" refers to the General Certificate o...  wiki_csai
# 841  [A level, or Advanced level, is a qualificatio...  wiki_csai
#
# [842 rows x 4 columns]

# %%
# Concaténation des datasets 
df_sourced = pd.concat([df_finance, df_medicine, df_open_qa, df_wiki], ignore_index=True)
df_sourced
# Out:
#                                                question  \
# 0     Historical P/E ratios of small-cap vs. large-c...
# 1     Should you co-sign a personal loan for a frien...
# 2     Should I avoid credit card use to improve our ...
# 3     Difference between 'split and redemption' of s...
# 4        Pros & cons of investing in gold vs. platinum?
# ...                                                 ...
# 7205             Please explain what is "Punched cards"
# 7206                Please explain what is "Paper tape"
# 7207               Please explain what is "BBC Model B"
# 7208                   Please explain what is "O level"
# 7209                   Please explain what is "A level"
#
#                                           human_answers  \
# 0     [There is most likely an error in the WSJ's da...
# 1     [I know this question has a lot of answers alr...
# 2     [If you pay it off before the cycle closes it ...
# 3     [It is the first time I encounter redemption p...
# 4     [Why Investors Buy Platinum is an old (1995) a...
# ...                                                 ...
# 7205  [A punched card (also punch card or punched-ca...
# 7206  [Punched tape or perforated paper tape is a fo...
# 7207  [The British Broadcasting Corporation Microcom...
# 7208  [The O-Level (Ordinary Level) is a subject-bas...
# 7209  [The A-Level (Advanced Level) is a subject-bas...
#
#                                         chatgpt_answers     source
# 0     [Historical price-to-earnings (P/E) ratios for...    finance
# 1     [Co-signing a personal loan for a friend or fa...    finance
# 2     [It can be a good idea to avoid using credit c...    finance
# 3     [Share split and redemption are two different ...    finance
# 4     [Gold and platinum are both precious metals th...    finance
# ...                                                 ...        ...
# 7205  [Punched cards were a means of storing and pro...  wiki_csai
# 7206  [Paper tape is a medium for storing and transm...  wiki_csai
# 7207  [The BBC Model B is a computer that was made b...  wiki_csai
# 7208  ["O level" refers to the General Certificate o...  wiki_csai
# 7209  [A level, or Advanced level, is a qualificatio...  wiki_csai
#
# [7210 rows x 4 columns]

# %%
# Afficher le nombre d'élements dans les listes de la colonne chatgpt_answers 
def count_sentences(list):
    return len(list)

df_sourced['answers_number'] = df_sourced['chatgpt_answers'].apply(count_sentences)
df_sourced
# Out:
#                                                question  \
# 0     Historical P/E ratios of small-cap vs. large-c...
# 1     Should you co-sign a personal loan for a frien...
# 2     Should I avoid credit card use to improve our ...
# 3     Difference between 'split and redemption' of s...
# 4        Pros & cons of investing in gold vs. platinum?
# ...                                                 ...
# 7205             Please explain what is "Punched cards"
# 7206                Please explain what is "Paper tape"
# 7207               Please explain what is "BBC Model B"
# 7208                   Please explain what is "O level"
# 7209                   Please explain what is "A level"
#
#                                           human_answers  \
# 0     [There is most likely an error in the WSJ's da...
# 1     [I know this question has a lot of answers alr...
# 2     [If you pay it off before the cycle closes it ...
# 3     [It is the first time I encounter redemption p...
# 4     [Why Investors Buy Platinum is an old (1995) a...
# ...                                                 ...
# 7205  [A punched card (also punch card or punched-ca...
# 7206  [Punched tape or perforated paper tape is a fo...
# 7207  [The British Broadcasting Corporation Microcom...
# 7208  [The O-Level (Ordinary Level) is a subject-bas...
# 7209  [The A-Level (Advanced Level) is a subject-bas...
#
#                                         chatgpt_answers     source  \
# 0     [Historical price-to-earnings (P/E) ratios for...    finance
# 1     [Co-signing a personal loan for a friend or fa...    finance
# 2     [It can be a good idea to avoid using credit c...    finance
# 3     [Share split and redemption are two different ...    finance
# 4     [Gold and platinum are both precious metals th...    finance
# ...                                                 ...        ...
# 7205  [Punched cards were a means of storing and pro...  wiki_csai
# 7206  [Paper tape is a medium for storing and transm...  wiki_csai
# 7207  [The BBC Model B is a computer that was made b...  wiki_csai
# 7208  ["O level" refers to the General Certificate o...  wiki_csai
# 7209  [A level, or Advanced level, is a qualificatio...  wiki_csai
#
#       answers_number
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 7205               1
# 7206               1
# 7207               1
# 7208               1
# 7209               1
#
# [7210 rows x 5 columns]

# %%
# Convertir les listes en chaines de caractères 
separator = ' ' 
df_sourced['human_answers'] = df_sourced['human_answers'].apply(lambda x: separator.join(x))
df_sourced['chatgpt_answers'] = df_sourced['chatgpt_answers'].apply(lambda x: separator.join(x))

df_sourced
# Out:
#                                                question  \
# 0     Historical P/E ratios of small-cap vs. large-c...
# 1     Should you co-sign a personal loan for a frien...
# 2     Should I avoid credit card use to improve our ...
# 3     Difference between 'split and redemption' of s...
# 4        Pros & cons of investing in gold vs. platinum?
# ...                                                 ...
# 7205             Please explain what is "Punched cards"
# 7206                Please explain what is "Paper tape"
# 7207               Please explain what is "BBC Model B"
# 7208                   Please explain what is "O level"
# 7209                   Please explain what is "A level"
#
#                                           human_answers  \
# 0     There is most likely an error in the WSJ's dat...
# 1     I know this question has a lot of answers alre...
# 2     If you pay it off before the cycle closes it w...
# 3     It is the first time I encounter redemption pr...
# 4     Why Investors Buy Platinum is an old (1995) ar...
# ...                                                 ...
# 7205  A punched card (also punch card or punched-car...
# 7206  Punched tape or perforated paper tape is a for...
# 7207  The British Broadcasting Corporation Microcomp...
# 7208  The O-Level (Ordinary Level) is a subject-base...
# 7209  The A-Level (Advanced Level) is a subject-base...
#
#                                         chatgpt_answers     source  \
# 0     Historical price-to-earnings (P/E) ratios for ...    finance
# 1     Co-signing a personal loan for a friend or fam...    finance
# 2     It can be a good idea to avoid using credit ca...    finance
# 3     Share split and redemption are two different c...    finance
# 4     Gold and platinum are both precious metals tha...    finance
# ...                                                 ...        ...
# 7205  Punched cards were a means of storing and proc...  wiki_csai
# 7206  Paper tape is a medium for storing and transmi...  wiki_csai
# 7207  The BBC Model B is a computer that was made by...  wiki_csai
# 7208  "O level" refers to the General Certificate of...  wiki_csai
# 7209  A level, or Advanced level, is a qualification...  wiki_csai
#
#       answers_number
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 7205               1
# 7206               1
# 7207               1
# 7208               1
# 7209               1
#
# [7210 rows x 5 columns]

# %%
# ETAPE 3 

import matplotlib.pyplot as plt
import seaborn as sns

source_count = df_sourced['source'].value_counts()

plt.figure(figsize=(10, 6))  
sns.barplot(x=source_count.index, y=source_count.values, palette='viridis')

plt.xlabel('Source')
plt.ylabel('Nombre de réponses')
plt.title('Nombre de réponses par source')

plt.show()
# Out:
# /tmp/ipykernel_7894/3440516945.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=source_count.index, y=source_count.values, palette='viridis')

# %%
# ETAPE 4
# Ajout d'une colonne qui indique le nombre de mots dans la réponse IA puis dans la réponse humaine

df_sourced['number_words_human'] = df_sourced['human_answers'].apply(lambda x: len(x.split()))
df_sourced['number_words_AI'] = df_sourced['chatgpt_answers'].apply(lambda x: len(x.split()))

df_sourced
# Out:
#                                                question  \
# 0     Historical P/E ratios of small-cap vs. large-c...
# 1     Should you co-sign a personal loan for a frien...
# 2     Should I avoid credit card use to improve our ...
# 3     Difference between 'split and redemption' of s...
# 4        Pros & cons of investing in gold vs. platinum?
# ...                                                 ...
# 7205             Please explain what is "Punched cards"
# 7206                Please explain what is "Paper tape"
# 7207               Please explain what is "BBC Model B"
# 7208                   Please explain what is "O level"
# 7209                   Please explain what is "A level"
#
#                                           human_answers  \
# 0     There is most likely an error in the WSJ's dat...
# 1     I know this question has a lot of answers alre...
# 2     If you pay it off before the cycle closes it w...
# 3     It is the first time I encounter redemption pr...
# 4     Why Investors Buy Platinum is an old (1995) ar...
# ...                                                 ...
# 7205  A punched card (also punch card or punched-car...
# 7206  Punched tape or perforated paper tape is a for...
# 7207  The British Broadcasting Corporation Microcomp...
# 7208  The O-Level (Ordinary Level) is a subject-base...
# 7209  The A-Level (Advanced Level) is a subject-base...
#
#                                         chatgpt_answers     source  \
# 0     Historical price-to-earnings (P/E) ratios for ...    finance
# 1     Co-signing a personal loan for a friend or fam...    finance
# 2     It can be a good idea to avoid using credit ca...    finance
# 3     Share split and redemption are two different c...    finance
# 4     Gold and platinum are both precious metals tha...    finance
# ...                                                 ...        ...
# 7205  Punched cards were a means of storing and proc...  wiki_csai
# 7206  Paper tape is a medium for storing and transmi...  wiki_csai
# 7207  The BBC Model B is a computer that was made by...  wiki_csai
# 7208  "O level" refers to the General Certificate of...  wiki_csai
# 7209  A level, or Advanced level, is a qualification...  wiki_csai
#
#       answers_number  number_words_human  number_words_AI
# 0                  1                  47              185
# 1                  1                 157              267
# 2                  1                  82              227
# 3                  1                 148              198
# 4                  1                  19              289
# ...              ...                 ...              ...
# 7205               1                 143              173
# 7206               1                 138              172
# 7207               1                 195              144
# 7208               1                 217               95
# 7209               1                 375              227
#
# [7210 rows x 7 columns]

# %%
# Graphique en barres qui représente le nombre de mots moyen par catégories 
mean_number_words_human = df_sourced.groupby('source')['number_words_human'].mean()

plt.figure(figsize=(10, 6))
sns.barplot(x=mean_number_words_human.index, y=mean_number_words_human.values, palette='viridis')

plt.xlabel('Source')
plt.ylabel('Nombre moyen de mots')
plt.title('Nombre moyen de mots par source (HUMAN)')

plt.show()
# Out:
# /tmp/ipykernel_7894/3026163787.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=mean_number_words_human.index, y=mean_number_words_human.values, palette='viridis')

# %%
mean_number_words_ai = df_sourced.groupby('source')['number_words_AI'].mean()

plt.figure(figsize=(10, 6))
sns.barplot(x=mean_number_words_ai.index, y=mean_number_words_ai.values, palette='viridis')

plt.xlabel('Source')
plt.ylabel('Nombre moyen de mots')
plt.title('Nombre moyen de mots par source (IA)')

plt.show()
# Out:
# /tmp/ipykernel_7894/2122952057.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=mean_number_words_ai.index, y=mean_number_words_ai.values, palette='viridis')

# %%
# !pip install wordcloud matplotlib
# Out:
# Requirement already satisfied: wordcloud in /opt/mamba/lib/python3.11/site-packages (1.9.3)
# Requirement already satisfied: matplotlib in /opt/mamba/lib/python3.11/site-packages (3.8.3)
# Requirement already satisfied: numpy>=1.6.1 in /opt/mamba/lib/python3.11/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /opt/mamba/lib/python3.11/site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/mamba/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# ETAPE 5 
# Identification des mots clés 
from collections import Counter
from wordcloud import WordCloud

all_text = ' '.join(df_sourced['human_answers'])

word_counts = Counter(all_text.split())

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')  
plt.axis('off')  
plt.title('Nuage de mots à partir des réponses humaines')
plt.show()

# %%
all_text = ' '.join(df_sourced['chatgpt_answers'])

word_counts_ia = Counter(all_text.split())

wordcloud_ia = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts_ia)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_ia, interpolation='bilinear')  
plt.axis('off')  
plt.title('Nuage de mots à partir des réponses AI')
plt.show()
